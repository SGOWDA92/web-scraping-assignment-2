# %% [markdown]
# # WEB-SCRAPING-ASSIGNMENT-2

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd 
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in
# “Bangalore” location. You have to scrape the job-title, job-location,
# company_name, full job-description. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill,Designations,Companies” field and enter
# “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6397a1d221c3544cc8f0a2736f61d41e", element="4a754dd4-1707-4ac1-ab9d-3fc9f62a3d97")>

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Bangalore")

# %%
search_btn = driver.find_element_by_xpath("//button[@class='btn']")
search_btn.click()

# %%
from selenium import webdriver
import time

# %%
for i in range(10):
    try:
        driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click()
    except:
        driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']/span").click()
        time.sleep(5)

# %%
job_title=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
        job_title.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
job_title
# Out:
# ['Tata UniStore Limited - Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Hiring For DATA Scientist - ON Contract Basis (3-6 Months)',
#  'Data Scientist',
#  'Lead NLP Data Scientist',
#  'Data Scientist',
#  'Job opportunity with Product Engineering firm - Data Scientist',
#  'Principal Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientists',
#  'Lead Data Scientist',
#  'Snr Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist - Time Series Forecasting',
#  'Data Scientist - Python | Lululemon',
#  'Data Scientist',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Cloud Data Scientist',
#  'Data Scientist',
#  'Snr Data Scientist - NBFC',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist - High growth VC backed Influencer Marketplace',
#  'Lead Data Scientist',
#  'Data Scientist - AI ML Team',
# ...

# %%
company_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"):
        company_name.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
company_name
# Out:
# ['ExecBoardinAsia',
#  'Quadrangle Search',
#  'Imaginea, part of Accenture',
#  'Smartdrive Systems India Pvt Ltd.',
#  'ERM India Private Limited',
#  'Bloom Consulting Services',
#  'APPTARIX',
#  'Newstar corporation',
#  'COUTURE AI PRIVATE LIMITED',
#  'TALENT500 TECH (INDIA) PRIVATE LIMITED',
#  'Unravel',
#  'String Bio',
#  'phData',
#  'CoStrategix Technologies Pvt. Ltd. Limited',
#  'Bloom Consulting Services',
#  'Xpheno',
#  'Walmart Labs',
#  'Hangar Worldwide',
#  'Benchire',
#  'ExecBoardinAsia',
#  'EIGENRISK BUSINESS SOLUTIONS INDIA PRIVATE LIMITED',
#  'Alliance Global Services IT India Pvt. Ltd.',
#  'Zdaly',
#  'Streamhub',
#  'Servian',
#  'RIVERSAND TECHNOLOGIES INDIA PRIVATE LIMITED',
#  'PPN Solutions Pvt Ltd.',
#  'Multi Recruit',
#  'SureEvents',
#  'Empower Retirement',
#  'Alliance Global Services IT India Pvt. Ltd.',
#  'Benchire',
#  'Nike India',
#  'CareerXperts Consulting',
#  'Bobble App',
#  'CareerXperts Consulting',
# ...

# %%
experience_list=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='ellipsis fleft fs12 lh16']"):
        experience_list.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
experience_list
# Out:
# ['11-15 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '4-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '3-5 Yrs',
#  'Not disclosed',
#  'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  '11-16 Yrs',
#  'Not disclosed',
#  'Mumbai, Bengaluru',
#  '5-10 Yrs',
#  'Not disclosed',
#  'Bengaluru',
#  '4-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '4-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '10-12 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '7-10 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '8-13 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '5-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '3-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '1-3 Yrs',
#  '2,00,000 - 2,50,000 PA.',
#  'Bangalore/Bengaluru(4th Block Jayanagar)',
#  '1-3 Yrs',
#  'Not disclosed',
#  'Bengaluru',
#  '3-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '8-10 Yrs',
#  'Not disclosed',
# ...

# %%
location_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
        location_tags.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
location_tags
# Out:
# ['Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bangalore/Bengaluru',
#  'Pune, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Pune, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Delhi / NCR',
#  'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Noida, Bangalore/Bengaluru',
#  'Noida, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bengaluru',
# ...

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in
# “Bangalore” location. You have to scrape the job-title, job-location, company_name,
# experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill,Designations,Companies” field and enter “Bangalore”
# in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6397a1d221c3544cc8f0a2736f61d41e", element="367efab6-67c2-45a4-bdc2-a51634827479")>

# %%
search_job.send_keys("Data Analyst")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Bangalore")

# %%
search_btn = driver.find_element_by_xpath("//button[@class='btn']")
search_btn.click()

# %%
job_title=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
        job_title.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
job_title
# Out:
# ['Data Scientist / Data Analyst -Business Analyst',
#  'Data Analyst',
#  'Data analysts',
#  'Data Analyst (2positions)//immediate Joiners//bangalore',
#  'Data analysts',
#  'Data Analyst',
#  'Data Analyst',
#  'Consultant-Data Analyst -Bangalore',
#  'Data Analyst - Category Demand Management (Revenue & Growth)',
#  'Data Analyst/ Data Consultant (Various Levels – Senior/ Mid/ Junior)',
#  'Senior Data Analyst - Data Lineage',
#  'Data Analyst (Contractual)',
#  'Data Analyst',
#  'Hiring Consultant Data Analyst Contractual',
#  'Analytics Product Data Analyst,',
#  'Assistant Manager II - Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Supply Data Analyst',
#  'Job Opportunity For Talent Data Analyst - Cornerstone OnDemand',
#  'Marketing Technology Data Analyst',
#  'Associate - Data Analyst ( Growth)',
#  'Associate - Data Analyst - Category Solutions',
#  'Clinical Data Analyst II',
#  'Opportunity with TEKsystems | Data Analyst',
# ...

# %%
company_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"):
        company_name.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
company_name
# Out:
# ['Mashreq Global Services Private Limited',
#  'Mashreq Global Services Private Limited',
#  'Lead School',
#  'Software Development',
#  'Tally Solutions Pvt. Ltd.',
#  'PowerSchool',
#  'Valuvox Business Solutions Private Limited',
#  'Draup',
#  'Naukri Premium - Employer Services',
#  'Gojek Tech',
#  'GO-JEK India',
#  'Gojek Tech',
#  'GO-JEK India',
#  'INTERTRUST GROUP',
#  'Boeing',
#  'Deutsche Bank',
#  'Wrackle Technologies Pvt Ltd',
#  'Chaitanya India Fin Credit Pvt Ltd',
#  'Near Pte. Ltd.',
#  'Near Pte. Ltd.',
#  'Near Pte. Ltd.',
#  'Capillary Technologies',
#  'Zeta Inc.',
#  'Myntra.com',
#  'KeepTruckin',
#  'Capco Technologies Pvt Ltd',
#  'Globals ITeS Pvt Ltd',
#  'Globals Inc.',
#  'Capco Technologies Pvt Ltd',
#  'Mavenir',
#  'HUSYS CONSULTING LIMITED',
#  'Kaplan',
#  'Kaplan Test Prep',
#  'AMPLIFY ANALYTIX INDIA PRIVATE LIMITED',
#  'Gojek Tech',
#  'GO-JEK India',
#  'Clarivate Analytics (TRCPL Projects Pvt Ltd.)',
#  'Gojek Tech',
#  'GO-JEK India',
# ...

# %%
experience_list
# Out:
# ['11-15 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '4-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '3-5 Yrs',
#  'Not disclosed',
#  'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  '11-16 Yrs',
#  'Not disclosed',
#  'Mumbai, Bengaluru',
#  '5-10 Yrs',
#  'Not disclosed',
#  'Bengaluru',
#  '4-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '4-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '10-12 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '7-10 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '8-13 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '5-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '3-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '1-3 Yrs',
#  '2,00,000 - 2,50,000 PA.',
#  'Bangalore/Bengaluru(4th Block Jayanagar)',
#  '1-3 Yrs',
#  'Not disclosed',
#  'Bengaluru',
#  '3-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '8-10 Yrs',
#  'Not disclosed',
# ...

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='ellipsis fleft fs12 lh16']"):
        experience_list.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    
    time.sleep(5)

# %%
experience_list
# Out:
# ['11-15 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '4-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '3-5 Yrs',
#  'Not disclosed',
#  'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  '11-16 Yrs',
#  'Not disclosed',
#  'Mumbai, Bengaluru',
#  '5-10 Yrs',
#  'Not disclosed',
#  'Bengaluru',
#  '4-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '4-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '10-12 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '7-10 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '8-13 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '5-9 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '3-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '1-3 Yrs',
#  '2,00,000 - 2,50,000 PA.',
#  'Bangalore/Bengaluru(4th Block Jayanagar)',
#  '1-3 Yrs',
#  'Not disclosed',
#  'Bengaluru',
#  '3-7 Yrs',
#  'Not disclosed',
#  'Bangalore/Bengaluru',
#  '8-10 Yrs',
#  'Not disclosed',
# ...

# %%
location_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
        location_tags.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
location_tags
# Out:
# ['Bangalore/Bengaluru(Electronic City +3)',
#  'Bangalore/Bengaluru(Electronic City +4)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Noida, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru',
#  'Bengaluru/Bangalore',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bengaluru/Bangalore',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Bangalore',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru(Electronic City +3)',
#  'Bangalore/Bengaluru(Electronic City +4)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Noida, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru',
#  'Bengaluru/Bangalore',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
# ...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the
# webpage as shown below:
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company_name,
# experience_required.
# The location filter to be used is “Delhi/NCR”
# The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill,Designations,Companies” field .
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6397a1d221c3544cc8f0a2736f61d41e", element="4d5a296e-2c6c-462d-8875-7c52a5971b0e")>

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Delhi/NCR")

# %%
search_btn = driver.find_element_by_xpath("//button[@class='btn']")
search_btn.click()

# %%
job_title=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
        job_title.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
job_title
# Out:
# ['Data Scientist / Data Analyst -Business Analyst',
#  'Data analytics / Data scientist intern (work from Home)',
#  'Chaayos is Looking For Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist - Machine Learning/Hadoop',
#  'Co-Founder & Principal Data Scientist/Senior Scientist - NLP/Python',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Looking For Data Scientist For Infogain',
#  'Data Scientist, Machine Learning',
#  'Senior Data Scientist (Algorithmic Trading)',
#  'Senior Data Scientist (Algorithmic Trading)',
#  'Data Scientist - Manufacturing Domain (SCM aspect) Location Open',
#  'Opening For Data Scientist in Axtria',
#  'Junior Data Scientist',
#  'Jr. Data Scientist, Gurgaon',
#  'Data Scientist',
#  'We are hiring- Data Scientist +Python- Noida',
#  'Senior Data Scientist - Machine Learning',
#  'Senior Data Scientist - Product Development Firm - IIT/ NIT/ BITS',
#  'Data Scientist - KPO - IIT/NIT/BITS',
#  'Big Data Scientist',
# ...

# %%
company_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"):
        company_name.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
company_name
# Out:
# ['Balbix',
#  'Corporate Connections',
#  'StriveX Consulting Pvt. Ltd',
#  'PubMatic India Pvt. Ltd.',
#  'Umbrella Infocare Pvt Ltd.',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting Pvt. Ltd',
#  'CONSULTBAE LLP',
#  'Jobwaala.com',
#  'Symmetrical Global Search Pvt Ltd',
#  'Farfetch',
#  'Optum Global Solutions (India) Private Limited',
#  'Huquo Consulting Pvt. Ltd',
#  'Microsoft Corporation',
#  'Lenskart.com',
#  'Ameriprise',
#  'Right Step Consulting',
#  'Huquo Consulting Pvt. Ltd',
#  'Huquo Consulting Pvt. Ltd',
#  'CIEL HR Services Pvt Ltd',
#  'Executive Vertical Consulting',
#  'Agreeya',
#  'Farfetch',
#  'Concirrus Ltd',
#  'CIEL HR Services Pvt Ltd',
#  'INTRAEDGE TECHNOLOGIES PRIVATE LIMITED',
#  'iQuest Management Consultants Pvt. Ltd',
#  'Hire on Cloud Technologies Pvt Ltd',
#  'IBM India Pvt. Limited',
#  'LEADERSHIP BOULEVARD PRIVATE LIMITED',
#  'HEALTH ARX TECHNOLOGIES PRIVATE LIMITED',
#  'Quattr Inc',
#  'PAGO Analytics',
# ...

# %%
experience_list=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='ellipsis fleft fs12 lh16']"):
        experience_list.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
experience_list
# Out:
# ['1-6 Yrs',
#  'Not disclosed',
#  'Gurgaon/Gurugram',
#  '1-3 Yrs',
#  'Not disclosed',
#  'Gurgaon',
#  '1-2 Yrs',
#  'Not disclosed',
#  'Ghaziabad',
#  '2-5 Yrs',
#  'Not disclosed',
#  'Delhi / NCR',
#  '1-5 Yrs',
#  'Not disclosed',
#  'Delhi',
#  '3-4 Yrs',
#  'Not disclosed',
#  'Noida',
#  '3-6 Yrs',
#  'Not disclosed',
#  'Noida',
#  '2-5 Yrs',
#  'Not disclosed',
#  'Noida',
#  '2-3 Yrs',
#  'Not disclosed',
#  'Gurgaon/Gurugram',
#  '1-2 Yrs',
#  'Not disclosed',
#  'Gurgaon/Gurugram',
#  '1-3 Yrs',
#  'Not disclosed',
#  'Gurgaon',
#  '1-4 Yrs',
#  'Not disclosed',
#  'Gurgaon',
#  '2-4 Yrs',
#  'Not disclosed',
#  'Gurgaon',
#  '1-5 Yrs',
#  '2,00,000 - more than 3,00,000 PA.',
#  'Gurgaon/Gurugram(Udyog Vihar Industrial Area Phase VI)',
#  '6-11 Yrs',
#  'Not disclosed',
#  'Noida',
#  '3-7 Yrs',
#  '5,00,000 - 9,50,000 PA.',
#  'Delhi / NCR(Okhla)',
#  '2-5 Yrs',
#  'Not disclosed',
#  'New Delhi',
#  '3-6 Yrs',
#  'Not disclosed',
#  'Gurgaon/Gurugram',
# ...

# %%
location_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
        location_tags.append(j.text)
        
    driver.find_element_by_xpath("//a[@class='fright fs14 btn-secondary br2']").click() 
    time.sleep(5)

# %%
location_tags
# Out:
# ['Noida(Sector-59 Noida)',
#  'Pune, Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Noida',
#  'Delhi / NCR',
#  'Delhi / NCR',
#  'Gurgaon/Gurugram',
#  'Mumbai, Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Gurgaon/Gurugram',
#  'Delhi / NCR',
#  'Gurgaon/Gurugram',
#  'Delhi / NCR',
#  'New Delhi',
#  'Delhi / NCR',
#  'Gurgaon/Gurugram, Delhi / NCR',
#  'Delhi / NCR',
#  'Gurgaon/Gurugram, Delhi / NCR',
#  'Gurgaon/Gurugram, Delhi NCR',
#  'Gurgaon/Gurugram',
#  'Noida',
#  'Gurgaon/Gurugram',
#  'Delhi / NCR',
#  'Gurgaon/Gurugram, Delhi / NCR',
#  'Noida',
#  'Gurgaon/Gurugram',
#  'Hyderabad/Secunderabad, Gurgaon/Gurugram, Delhi / NCR',
#  'Delhi / NCR',
#  'Gurgaon/Gurugram, haryana',
#  'Gurgaon/Gurugram, Delhi / NCR',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram, Delhi / NCR',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Pune, Gurgaon/Gurugram',
#  'Noida',
#  'Gurgaon, Bengaluru',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Noida',
# ...

# %% [markdown]
# # Q4: Write a python program to scrape data for first 10 job results for Data scientist
# Designation in Noida location. You have to scrape company_name, No. of days
# ago when job was posted, Rating of the company.
# This task will be done in following steps:
# 1. first get the webpage https://www.glassdoor.co.in/index.htm
# 2. Enter “Data Scientist” in “Job Title,Keyword,Company” field and enter “Noida”
# in “location” field.
# 3. Then click the search button. You will land up in the below page:
# 4. Then scrape the data for the first 10 jobs results you get in the above shown
# page
# 5. Finally create a dataframe of the scraped data.

# %%
url = "http://www.glassdoor.co.in/index.htm"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//a")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6397a1d221c3544cc8f0a2736f61d41e", element="96fd86ae-eb4e-44c6-b36f-3a0961915e4a")>

# %%
search_job = driver.find_element_by_xpath("//input[@class='css-1etjok6']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6397a1d221c3544cc8f0a2736f61d41e", element="39d45892-1b05-4744-82b1-0c8ee5059bf4")>

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc = driver.find_element_by_xpath("//input[@class='css-1etjok6']")
search_loc.send_keys("Noida(india)")

# %%
company_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='css-87uc0g e1tk4kwz1']"):
        company_name.append(j.text)
    time.sleep(5)

# %%
company_name
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Jobs',
#  'Companies',
#  'Salaries',
#  'Interviews',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
location_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='pr-xxsm css-1ndif2q e1rrn5ka0']"):
        location_name.append(j.text)
    time.sleep(5)

# %%
location_name
# Out:
# ['India',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Greater Noida',
#  'Gurgaon',
#  'New Delhi',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'New Delhi',
#  'New Delhi',
#  'Gurgaon',
#  'Gurgaon',
#  'New Delhi',
#  'Noida',
#  'Vasant Kunj',
#  'New Delhi',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Vasant Kunj',
#  'Noida',
#  'Noida',
#  'India',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Greater Noida',
#  'Gurgaon',
#  'New Delhi',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'New Delhi',
#  'New Delhi',
#  'Gurgaon',
#  'Gurgaon',
#  'New Delhi',
#  'Noida',
#  'Vasant Kunj',
#  'New Delhi',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Vasant Kunj',
#  'Noida',
#  'Noida',
#  'India',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Greater Noida',
#  'Gurgaon',
#  'New Delhi',
#  'Noida',
# ...

# %%
jobpostdays_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='d-flex align-items-end pl-std css-mi55ob']"):
        jobpostdays_tags.append(j.text)
    time.sleep(5)

# %%
jobpostdays_tags
# Out:
# ['30d+',
#  '24h',
#  '30d+',
#  '24h',
#  '2d',
#  '30d+',
#  '30d+',
#  '30d+',
#  '30d+',
#  '3d',
#  '30d+',
#  '1d',
#  '1d',
#  '4d',
#  '30d+',
#  '30d+',
#  '6d',
#  '30d+',
#  '30d+',
#  '8d',
#  '30d+',
#  '4d',
#  '30d+',
#  '4d',
#  '30d+',
#  '30d+',
#  '30d+',
#  '30d+',
#  '9d',
#  '30d+',
#  '30d+',
#  '24h',
#  '30d+',
#  '24h',
#  '2d',
#  '30d+',
#  '30d+',
#  '30d+',
#  '30d+',
#  '3d',
#  '30d+',
#  '1d',
#  '1d',
#  '4d',
#  '30d+',
#  '30d+',
#  '6d',
#  '30d+',
#  '30d+',
#  '8d',
#  '30d+',
#  '4d',
#  '30d+',
#  '4d',
#  '30d+',
#  '30d+',
#  '30d+',
#  '30d+',
#  '9d',
#  '30d+',
#  '30d+',
#  '24h',
#  '30d+',
#  '24h',
#  '2d',
#  '30d+',
#  '30d+',
#  '30d+',
#  '30d+',
#  '3d',
#  '30d+',
#  '1d',
#  '1d',
#  '4d',
#  '30d+',
#  '30d+',
#  '6d',
#  '30d+',
#  '30d+',
#  '8d',
#  '30d+',
#  '4d',
#  '30d+',
#  '4d',
#  '30d+',
#  '30d+',
#  '30d+',
#  '30d+',
#  '9d',
#  '30d+',
#  '30d+',
#  '24h',
#  '30d+',
#  '24h',
#  '2d',
#  '30d+',
#  '30d+',
# ...

# %% [markdown]
# # Q5: Write a python program to scrape the salary data for Data Scientist designation
# in Noida location.
# You have to scrape Company name, Number of salaries, Average salary, Min
# salary, Max Salary.
# The above task will be, done as shown in the below steps:
# 1. first get the webpage https://www.glassdoor.co.in/Salaries/index.htm
# 2. Enter “Data Scientist” in Job title field and “Noida” in location field.
# 3. Click the search button.
# 4. After that you will land on the below page
# You have to scrape whole data from this webpage
# 5. Scrape data for first 10 companies. Scrape the min salary, max salary, company
# name, Average salary and rating of the company.
# 6.Store the data in a dataframe.

# %%
url = "http://www.glassdoor.co.in/Salaries/index.htm"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//a")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6397a1d221c3544cc8f0a2736f61d41e", element="efddbbae-e6d5-4930-be7d-024bb3b4a3d8")>

# %%
search_job = driver.find_element_by_xpath("//input[@class='css-1etjok6']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6397a1d221c3544cc8f0a2736f61d41e", element="267747c6-394b-4414-b35e-e69a955501e0")>

# %%
search_job.send_keys("Data Scientist")

# %%
search_loc = driver.find_element_by_xpath("//input[@class='css-1etjok6']")
search_loc.send_keys("Noida(india)")

# %%
company_name=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span"):
        company_name.append(j.text)
    time.sleep(5)

# %%
company_name
# Out:
# ['Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  'Fresenius Kabi Oncology\n3.6',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
salaries_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='css-1imh2hq e1wijj242']"):
        salaries_tags.append(j.text)
    time.sleep(5)

# %%
salaries_tags
# Out:
# ['₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)',
#  '₹1,000K - ₹1,200K (Employer Est.)',
#  '₹600K (Employer Est.)']

# %%
location_names=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='pr-xxsm css-1ndif2q e1rrn5ka0']"):
        location_names.append(j.text)
    time.sleep(5)

# %%
location_names
# Out:
# ['Gurgaon',
#  'India',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'New Delhi',
#  'Greater Noida',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'Gurgaon',
#  'Vasant Kunj',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Noida',
#  'New Delhi',
#  'Noida',
#  'Vasant Kunj',
#  'Gurgaon',
#  'India',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'New Delhi',
#  'Greater Noida',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'Gurgaon',
#  'Vasant Kunj',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Noida',
#  'New Delhi',
#  'Noida',
#  'Vasant Kunj',
#  'Gurgaon',
#  'India',
#  'Noida',
#  'Gurgaon',
#  'Noida',
#  'Noida',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'New Delhi',
#  'Greater Noida',
# ...

# %%
reviews_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='css-1m5m32b e1tk4kwz2']"):
        reviews_tags.append(j.text)
    time.sleep(5)

# %%
reviews_tags
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %% [markdown]
# # Q6 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to
# scrape four attributes:
# 1. Brand
# 2. Product Description
# 3 .price
# 4.Discount%
# 1. Go to flipkart webpage by url https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and
# more” is written and click the search icon
# 3. after that you will reach to a webpage having a lot of sunglasses. From this page
# you can scrap the required data as usual.
# 4. after scraping data from the first page, go to the “Next” Button at the bottom of
# the page , then click on it
# 5. Now scrape data from this page as usual
# 6. repeat this until you get data for 100 sunglasses

# %%
url = "http://www.filpkart.com/"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input[@class='_3704LK']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6397a1d221c3544cc8f0a2736f61d41e", element="bc1189bf-a54d-4779-b225-29fada3a17f3")>

# %%
brand_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        brand_tags.append(j.text)
    time.sleep(5)

# %%
brand_tags
# Out:
# ['LIZA ANGEL',
#  'NuVew',
#  'Fastrack',
#  'PIRASO',
#  'PIRASO',
#  'PIRASO',
#  'Fastrack',
#  'NuVew',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Fastrack',
#  'ZOSTAL',
#  'DEIXELS',
#  'PHENOMENAL',
#  'PIRASO',
#  'NuVew',
#  'ROZZETTA CRAFT',
#  'GANSTA',
#  'HIPPON',
#  'AISLIN',
#  'PIRASO',
#  'Fastrack',
#  'PHENOMENAL',
#  'NuVew',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'CRYSTAL CART',
#  'DEIXELS',
#  'Silver Kartz',
#  'Fastrack',
#  'Spexra',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'Flizz',
#  'AISLIN',
#  'PIRASO',
#  'NuVew',
#  'ROYAL SON',
#  'CRYSTAL CART',
#  'LIZA ANGEL',
#  'NuVew',
#  'Fastrack',
#  'PIRASO',
#  'PIRASO',
#  'PIRASO',
#  'Fastrack',
#  'NuVew',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Fastrack',
#  'ZOSTAL',
#  'DEIXELS',
#  'PHENOMENAL',
#  'PIRASO',
#  'NuVew',
#  'ROZZETTA CRAFT',
#  'GANSTA',
#  'HIPPON',
#  'AISLIN',
#  'PIRASO',
#  'Fastrack',
#  'PHENOMENAL',
#  'NuVew',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'Fastrack',
# ...

# %%
price_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        price_tags.append(j.text)
    time.sleep(5)

# %%
price_tags
# Out:
# ['₹199',
#  '₹364',
#  '₹570',
#  '₹250',
#  '₹250',
#  '₹250',
#  '₹674',
#  '₹156',
#  '₹404',
#  '₹1,085',
#  '₹536',
#  '₹218',
#  '₹213',
#  '₹399',
#  '₹349',
#  '₹290',
#  '₹499',
#  '₹301',
#  '₹251',
#  '₹1,079',
#  '₹385',
#  '₹733',
#  '₹399',
#  '₹237',
#  '₹319',
#  '₹499',
#  '₹638',
#  '₹369',
#  '₹219',
#  '₹259',
#  '₹719',
#  '₹209',
#  '₹449',
#  '₹183',
#  '₹399',
#  '₹525',
#  '₹323',
#  '₹227',
#  '₹399',
#  '₹487',
#  '₹199',
#  '₹364',
#  '₹570',
#  '₹250',
#  '₹250',
#  '₹250',
#  '₹674',
#  '₹156',
#  '₹404',
#  '₹1,085',
#  '₹536',
#  '₹218',
#  '₹213',
#  '₹399',
#  '₹349',
#  '₹290',
#  '₹499',
#  '₹301',
#  '₹251',
#  '₹1,079',
#  '₹385',
#  '₹733',
#  '₹399',
#  '₹237',
#  '₹319',
#  '₹499',
#  '₹638',
#  '₹369',
#  '₹219',
#  '₹259',
#  '₹719',
#  '₹209',
#  '₹449',
#  '₹183',
#  '₹399',
#  '₹525',
#  '₹323',
#  '₹227',
#  '₹399',
#  '₹487',
#  '₹199',
#  '₹364',
#  '₹570',
#  '₹250',
#  '₹250',
#  '₹250',
#  '₹674',
#  '₹156',
#  '₹404',
#  '₹1,085',
# ...

# %%
Discount_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span"):
        Discount_tags.append(j.text)
    time.sleep(5)

# %%
Discount_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  'PRICE',
#  '?',
#  '1361 MORE',
#  'Need help?',
#  'Help me decide',
#  'Showing 1 – 40 of 86,279 results for "sunglasses"',
#  'sunglasses',
#  'Sort By',
#  'Ad',
#  '75% off',
#  'Size',
#  'Ad',
#  '65% off',
#  'Size',
#  '28% off',
#  '',
#  '84% off',
#  '84% off',
#  '',
#  '84% off',
#  '25% off',
#  '',
#  'Ad',
#  '79% off',
#  '79% off',
#  '16% off',
#  '32% off',
#  'Ad',
#  '78% off',
#  '82% off',
#  '80% off',
#  '78% off',
#  'Ad',
#  '68% off',
#  '77% off',
#  '84% off',
#  '79% off',
#  'Ad',
#  '73% off',
#  '85% off',
#  '18% off',
#  '80% off',
#  'Ad',
#  '69% off',
#  '78% off',
#  '77% off',
#  '20% off',
#  'Ad',
#  '75% off',
#  '72% off',
#  '82% off',
#  '10% off',
#  'Ad',
#  '80% off',
#  '79% off',
#  '81% off',
#  '81% off',
#  'Ad',
#  '75% off',
# ...

# %%
product_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='_2Tpdn3']"):
        product_tags.append(j.text)
    time.sleep(5)

# %%
product_tags
# Out:
# ['Or Pay ₹541 + ',
#  ' 29',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ',
#  '₹640 + ',
#  ' 34',
#  'Or Pay ₹1,030 + ',
#  ' 55',
#  'Or Pay ₹509 + ',
#  ' 27',
#  'Or Pay ₹331 + ',
#  ' 18',
#  'Or Pay ₹365 + ',
#  ' 20',
#  'Or Pay ₹696 + ',
#  ' 37',
#  'Or Pay ₹606 + ',
#  ' 32',
#  'Or Pay ₹246 + ',
#  ' 13',
#  'Or Pay ₹306 + ',
#  ' 17',
#  'Or Pay ₹541 + ',
#  ' 29',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ',
#  '₹640 + ',
#  ' 34',
#  'Or Pay ₹1,030 + ',
#  ' 55',
#  'Or Pay ₹509 + ',
#  ' 27',
#  'Or Pay ₹331 + ',
#  ' 18',
#  'Or Pay ₹365 + ',
#  ' 20',
#  'Or Pay ₹696 + ',
#  ' 37',
#  'Or Pay ₹606 + ',
#  ' 32',
#  'Or Pay ₹246 + ',
#  ' 13',
#  'Or Pay ₹306 + ',
#  ' 17',
#  'Or Pay ₹541 + ',
#  ' 29',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ₹237 + ',
#  ' 13',
#  'Or Pay ',
#  '₹640 + ',
#  ' 34',
# ...

# %% [markdown]
# # Q7: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to
# go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb-includesearpods-poweradapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace.
#         These are
# 1. Rating
# 2. Review_summary
# 3. Full review
# You have to scrape this data for first 100 reviews

# %%
import selenium
import pandas as pd 
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = " https://www.flipkart.com/apple-iphone-11-black-64-gb-includesearpods-poweradapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input[@class='_3704LK']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="082762a8cb8cd3f890a0a79c52b57db1", element="d25a4f02-b73e-4d78-8e30-7307ef5dead2")>

# %%
rating_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span"):
        rating_tags.append(j.text)
    time.sleep(5)

# %%
rating_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  '',
#  'PRICE',
#  '?',
#  'Need help?',
#  'Help me decide',
#  'Showing 1 – 24 of 82 results for "iphone 11"',
#  'iphone 11',
#  'Sort By',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  'Temporarily Unavailable',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  'Temporarily Unavailable',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
# ...

# %%
reviewsummary_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span"):
        reviewsummary_tags.append(j.text)
    time.sleep(5)

# %%
reviewsummary_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  '',
#  'PRICE',
#  '?',
#  'Need help?',
#  'Help me decide',
#  'Showing 1 – 24 of 82 results for "iphone 11"',
#  'iphone 11',
#  'Sort By',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  'Temporarily Unavailable',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  'Temporarily Unavailable',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
# ...

# %%
Fullreviews_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span"):
        Fullreviews_tags.append(j.text)
    time.sleep(5)

# %%
Fullreviews_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  '',
#  'PRICE',
#  '?',
#  'Need help?',
#  'Help me decide',
#  'Showing 1 – 24 of 82 results for "iphone 11"',
#  'iphone 11',
#  'Sort By',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  'Temporarily Unavailable',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings & 4,845 Reviews',
#  '63,399 Ratings ',
#  '&',
#  ' 4,845 Reviews',
#  '8% off',
#  'Temporarily Unavailable',
#  '',
#  'Add to Compare',
#  '4.6',
#  '63,399 Ratings & 4,845 Reviews',
# ...

# %%
rating_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK']"):
        rating_tags.append(j.text)
    time.sleep(5)

# %%
rating_tags
# Out:
# ['4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
# ...

# %% [markdown]
# # Q8: Scrape data for first 100 sneakers you find when you visit flipkart.com and
# search for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker :
# 1. Brand
# 2. Product Description
# 3. Price
# 4. discount %

# %%
url = "https://www.flipkart.com/"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input[@class='_3704LK']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="082762a8cb8cd3f890a0a79c52b57db1", element="3ff2cc10-a844-4e46-a8eb-ebb522230e7f")>

# %%
brand_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        brand_tags.append(j.text)
    time.sleep(5)

# %%
brand_tags
# Out:
# ['AMICO',
#  'Kavon',
#  'Shoes Bank',
#  'PEHANOSA',
#  'bluemaker',
#  'ORICUM',
#  'Robbie jones',
#  'BRUTON',
#  'VIPSJAZZY',
#  'CALCADOS',
#  'Chevit',
#  'believe',
#  'D-SNEAKERZ',
#  'SCATCHITE',
#  'Numenzo',
#  'Nilatin',
#  'Stefano Rads',
#  'HOTSTYLE',
#  '3SIX5',
#  'BRUTON',
#  'Kraasa',
#  'TR',
#  'Nilatin',
#  'Echor',
#  'Robbie jones',
#  'Chevit',
#  'Birde',
#  'Echor',
#  'Zsyto',
#  'ESSENCE',
#  'Birde',
#  'ELISEO',
#  'ASTEROID',
#  'bluemaker',
#  'bluemaker',
#  'ELISEO',
#  'World Wear Footwear',
#  'Jokatoo',
#  'restinfoot',
#  'BRUTON',
#  'AMICO',
#  'Kavon',
#  'Shoes Bank',
#  'PEHANOSA',
#  'bluemaker',
#  'ORICUM',
#  'Robbie jones',
#  'BRUTON',
#  'VIPSJAZZY',
#  'CALCADOS',
#  'Chevit',
#  'believe',
#  'D-SNEAKERZ',
#  'SCATCHITE',
#  'Numenzo',
#  'Nilatin',
#  'Stefano Rads',
#  'HOTSTYLE',
#  '3SIX5',
#  'BRUTON',
#  'Kraasa',
#  'TR',
#  'Nilatin',
#  'Echor',
#  'Robbie jones',
#  'Chevit',
#  'Birde',
#  'Echor',
#  'Zsyto',
# ...

# %%
productdescription_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span"):
        productdescription_tags.append(j.text)
    time.sleep(5)

# %%
productdescription_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  '',
#  '',
#  'PRICE',
#  '?',
#  '1656 MORE',
#  '12 MORE',
#  '19 MORE',
#  'Showing 1 – 40 of 11,23,504 results for "sneakers"',
#  'sneakers',
#  'Sort By',
#  'Ad',
#  '51% off',
#  'Size',
#  'Ad',
#  '68% off',
#  '',
#  '65% off',
#  '50% off',
#  '45% off',
#  '58% off',
#  '50% off',
#  '',
#  'Ad',
#  '76% off',
#  '57% off',
#  '62% off',
#  '73% off',
#  'Ad',
#  '50% off',
#  '44% off',
#  '58% off',
#  '60% off',
#  'Ad',
#  '67% off',
#  '65% off',
#  '43% off',
#  '57% off',
#  'Ad',
#  '87% off',
#  '44% off',
#  '81% off',
#  '67% off',
#  'Ad',
#  '40% off',
#  '54% off',
#  '55% off',
#  '62% off',
#  'Ad',
#  '40% off',
#  '70% off',
#  '55% off',
#  '43% off',
#  'Ad',
#  '50% off',
#  '72% off',
#  '45% off',
#  '45% off',
#  'Ad',
#  '55% off',
#  '81% off',
# ...

# %%
import selenium
import pandas as pd 
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome("chromedriver.exe")
url = "https://www.flipkart.com/"
driver.get(url)

# %%
price_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        price_tags.append(j.text)
    time.sleep(5)

# %%
price_tags
# Out:
# ['₹424',
#  '₹1,579',
#  '₹499',
#  '₹211',
#  '₹398',
#  '₹399',
#  '₹377',
#  '₹819',
#  '₹499',
#  '₹449',
#  '₹426',
#  '₹449',
#  '₹449',
#  '₹748',
#  '₹473',
#  '₹449',
#  '₹429',
#  '₹365',
#  '₹398',
#  '₹254',
#  '₹214',
#  '₹242',
#  '₹283',
#  '₹1,048',
#  '₹474',
#  '₹416',
#  '₹769',
#  '₹449',
#  '₹407',
#  '₹405',
#  '₹673',
#  '₹1,048',
#  '₹449',
#  '₹293',
#  '₹304',
#  '₹319',
#  '₹283',
#  '₹449',
#  '₹439',
#  '₹2,794',
#  '₹424',
#  '₹1,579',
#  '₹499',
#  '₹211',
#  '₹398',
#  '₹399',
#  '₹377',
#  '₹819',
#  '₹499',
#  '₹449',
#  '₹426',
#  '₹449',
#  '₹449',
#  '₹748',
#  '₹473',
#  '₹449',
#  '₹429',
#  '₹365',
#  '₹398',
#  '₹254',
#  '₹214',
#  '₹242',
#  '₹283',
#  '₹1,048',
#  '₹474',
#  '₹416',
#  '₹769',
#  '₹449',
#  '₹407',
#  '₹405',
#  '₹673',
#  '₹1,048',
#  '₹449',
#  '₹293',
#  '₹304',
#  '₹319',
#  '₹283',
#  '₹449',
#  '₹439',
#  '₹2,794',
#  '₹424',
#  '₹1,579',
#  '₹499',
#  '₹211',
#  '₹398',
#  '₹399',
#  '₹377',
#  '₹819',
#  '₹499',
# ...

# %%
discount_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//span"):
        discount_tags.append(j.text)
    time.sleep(5)

# %%
discount_tags
# Out:
# ['Plus',
#  'Cart',
#  'Electronics',
#  'TVs & Appliances',
#  'Men',
#  'Women',
#  'Baby & Kids',
#  'Home & Furniture',
#  'Sports, Books & More',
#  'Filters',
#  'CATEGORIES',
#  '',
#  '',
#  '',
#  'PRICE',
#  '?',
#  '1656 MORE',
#  '12 MORE',
#  '19 MORE',
#  'Showing 1 – 40 of 10,93,876 results for "sneakers"',
#  'sneakers',
#  'Sort By',
#  'Ad',
#  '57% off',
#  'Size',
#  'Ad',
#  '56% off',
#  '',
#  '81% off',
#  '',
#  '57% off',
#  '60% off',
#  'Size',
#  '60% off',
#  'Size',
#  '62% off',
#  '',
#  'Ad',
#  '59% off',
#  '50% off',
#  '55% off',
#  '78% off',
#  'Ad',
#  '55% off',
#  '55% off',
#  '62% off',
#  '73% off',
#  'Ad',
#  '55% off',
#  '57% off',
#  '44% off',
#  '60% off',
#  'Ad',
#  '80% off',
#  '57% off',
#  '65% off',
#  '43% off',
#  'Ad',
#  '71% off',
#  '76% off',
#  '58% off',
#  '23% off',
#  'Ad',
#  '55% off',
#  '68% off',
#  '59% off',
#  '66% off',
#  'Ad',
#  '71% off',
#  '55% off',
#  '41% off',
#  '69% off',
#  'Ad',
# ...

# %% [markdown]
# # Q9: Go to the link - https://www.myntra.com/shoes
# Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, as shown in
# the below image

# %%
import selenium
import pandas as pd 
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome("chromedriver.exe")
url ="https://www.myntra.com/shoes"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//a[@class='myntraweb-sprite desktop-logo sprites-headerLogo']")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="afc16a8c-2ff1-470d-91cd-650d14d9a02b")>

# %%
brand_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//h3"):
        brand_tags.append(j.text)
    time.sleep(5)

# %%
brand_tags
# Out:
# ['Heel & Buckle London',
#  'Nike',
#  'Nike',
#  'Nike',
#  'Nike',
#  'Nike',
#  'Nike',
#  'Nike',
#  'PUMA Motorsport',
#  'Hush Puppies',
#  'UNDER ARMOUR',
#  'FORCLAZ By Decathlon',
#  'Nike',
#  'UNDER ARMOUR',
#  'Puma',
#  'Cole Haan',
#  'UNDER ARMOUR',
#  'Puma',
#  'UNDER ARMOUR',
#  'ASICS',
#  'ASICS',
#  'ASICS',
#  'ALDO',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'ASICS',
#  'Reebok',
#  'ADIDAS',
#  'Puma',
#  'UNDER ARMOUR',
#  'Cole Haan',
#  'Teakwood Leathers',
#  'Puma',
#  'Teakwood Leathers',
#  'Puma',
#  'UNDER ARMOUR',
#  'J.FONTINI',
#  'UNDER ARMOUR',
#  'Geox',
#  'Kenneth Cole',
#  'Saint G',
#  'DAVINCHI',
#  'Ruosh',
#  'Bugatti',
#  'Saint G',
#  'ADIDAS',
#  'Kalenji By Decathlon',
#  'Levis',
#  'Cole Haan',
#  'Puma',
#  'STYLISH SHOES TO ELEVATE YOUR WARDROBE',
#  'SPORTY AND STYLISH WITH SNEAKERS',
#  'WHAT SHOES TO WEAR WITH KURTA?',
#  'WHAT TYPES OF SHOES ARE FOR A PARTY?',
#  'WHICH ARE THE TOP 5 SHOE TYPES USED MOST?',
# ...

# %%
shoedescription_tags=[]

# %%
for i in range(100):
    for j in driver.find_elements_by_xpath("//h4"):
        shoedescription_tags.append(j.text)
    time.sleep(5)

# %%
shoedescription_tags
# Out:
# ['Bundles',
#  'Country of Origin',
#  'Size',
#  'Women Peep Toe Heels',
#  '',
#  'Women PEGASUS 37 Running Shoes',
#  '',
#  'Men JOYRIDE Running Shoes',
#  '',
#  'Unisex COSMIC UNITY Basketball',
#  '',
#  'Men JORDAN DELTA Basketball',
#  '',
#  'Men ZOOM FREAK 2 Basketball',
#  '',
#  'Men KD13 EP Basketball Shoes',
#  '',
#  'Women REACT Running Shoes',
#  '',
#  'Unisex Mercedes Running Shoes',
#  '',
#  'Men Solid Leather Formal Slip-Ons',
#  '',
#  'Men HOVR Strt Walking Shoes',
#  '',
#  'TREKKING 100 Boots',
#  '',
#  'Men JORDAN DELTA Sneakers',
#  '',
#  'Charged Rogue 2 Wide 2E Shoes',
#  '',
#  'Unisex RS-Fast Nano Sneakers',
#  '',
#  'Men ZEROGRAND GLOBAL SLIP ON',
#  '',
#  'Women TriBase Reign 2 Training',
#  '',
#  'Men UltraRide Running Shoes',
#  '',
#  'Men Liquify Running Shoes',
#  '',
#  'Women Running Shoes',
#  '',
#  'Women Running Shoes',
#  '',
#  'Men Black Sports Shoes',
#  '',
#  'Men Solid Leather Formal Loafers',
#  '',
# ...

# %% [markdown]
# # Q10: Go to webpage https://www.amazon.in/
#  Enter “Laptop” in the search field and then click the search icon.
#  Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the
# below image

# %%
url ="http://www.amazon.in"
driver.get(url)

# %%
search_job = driver.find_element_by_xpath("//input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="d198876f-24fc-4b0b-969a-27f34c9ef6c4")>

# %%
title_tags=driver.find_elements_by_xpath("//h2")
title_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="0429b388-7686-40ee-8018-2ad7448c1df7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="792ad99c-12ff-45f5-81cd-7b591ccd0a31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="7b76b0a9-79d5-4b61-a6c7-8f0bf9707436")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="2e8541f4-f942-428d-9d45-3b089c363aad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="81271c0b-d0f5-4b4a-9b76-7616092b1c5c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="13adef60-9f2e-4183-8006-1e7a69fd6864")>,
# ...

# %%
title_names=[]

for i in title_tags:
    title_names.append(i.text)
title_names
# Out:
# ['Lenovo Ideapad 5 Intel i7 11th Gen 15.6" Thin and Light (16GB/512SSD/Win10 +Office Home/Intel Iris Xe Graphics/Graphite Grey/1.66kg), 82FG0117IN',
#  'HP Pavilion (2021) Thin & Light 11th Gen Core i7 Laptop, 16 GB RAM, 1TB SSD, Iris Xe Graphics, 14" (35.56cms) FHD Screen, Windows 10, MS Office, Backlit Keyboard (14-dv0058TU)',
#  'Mi Notebook Horizon Edition 14 Intel Core i5-10210U 10th Gen 14-inch (35.56 cms) Thin and Light Laptop(8GB/512GB SSD/Windows 10/Nvidia MX350 2GB Graphics/Grey/1.35Kg), XMA1904-AR+Webcam',
#  'Life Digital Laptop 15.6-inch (39.62 cms) (Intel Core i7, 4GB RAM, 256GB SSD, Windows 10), ZED AIR CX7',
#  'Dell Inspiron 5410 14" FHD Touch Display 2in1 Laptop (i7-1165G7 / 16GB / 512GB SSD / Integrated Graphics / Win 10 + MSO / Backlit KB + FPR + Active Pen / Silver Metal Color) D560469WIN9S',
# ...

# %%
price_tags=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
price_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="b7f16ef6-d3a5-4de9-b3fd-49ec693fe769")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="859ff4ff-97f3-4f72-badf-4f82e35b7877")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="6d7d3876-a783-4301-a6a6-cf95e1ee149c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="bf1d2fc3-528d-45f0-a4d0-db7c07d8c551")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="10918efe-4db3-4843-9703-18b73ff9b816")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="cda591c5-7759-44e4-af04-ff202db838c0")>,
# ...

# %%
price_names=[]

for i in price_tags:
    price_names.append(i.text)
price_names
# Out:
# ['76,990',
#  '84,990',
#  '54,999',
#  '26,990',
#  '89,990',
#  '86,990',
#  '97,990',
#  '2,69,990',
#  '89,990',
#  '44,999',
#  '1,74,990',
#  '98,990',
#  '77,186',
#  '77,990',
#  '63,599',
#  '1,40,900',
#  '86,290',
#  '78,990',
#  '41,999',
#  '1,04,980',
#  '50,999',
#  '50,999',
#  '40,999',
#  '83,000']

# %%
Ratings_tags=driver.find_elements_by_xpath("//span[@class='a-size-base']")
Ratings_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="4792d0ed-1c71-403d-b639-e6a174274583")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="b8631c72-8738-4d56-a946-b78288756a8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="0687de7c-ca05-4f15-8de8-6c00dfe22079")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="205d74d3-eb90-44d6-b69c-1febd12dae91")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="0ac4aeac-5772-4a50-9b55-823c5f725122")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="21ab2db4ed1e5b5ad659f880f23b724b", element="7ec2b1fd-419e-4572-a920-947745b2d35a")>,
# ...

# %%
Ratings_names=[]

for i in Ratings_tags:
    Ratings_names.append(i.text)
Ratings_names
# Out:
# ['3',
#  '89',
#  '821',
#  '8',
#  '19',
#  '11',
#  '8',
#  '7',
#  '1',
#  '18',
#  '64',
#  '1',
#  '92',
#  '32',
#  '6',
#  '98',
#  '23',
#  '245',
#  '21',
#  '3',
#  '14',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']
